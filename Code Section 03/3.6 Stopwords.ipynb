# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'few', 'has', 'whatever', 'of', 'would', 'was', 'mine', 'the', 'whenever', 'they', 'whose', 'towards', 'who', 'much', 'quite', 'thru', '’s', 'more', 'least', 'various', 'without', 'somewhere', 'anything', 'first', 'however', 'perhaps', 'something', 'did', 'in', 'we', 'amongst', 'them', 'whereas', 'amount', "'re", 'while', 'your', 'around', 'so', 'to', 'besides', 'forty', 'and', 'nevertheless', 'seem', 'me', 'everywhere', 'myself', 'down', 'those', 'six', 'he', 'because', 'top', 'here', 'nowhere', 'upon', 'over', 'enough', 'during', 'no', 'moreover', 'sometime', 'for', 'name', 'yet', 'his', 'used', 'anyone', 'might', 'twelve', 'became', 'himself', 'thereupon', 'whither', 'should', 'had', 'noone', 'before', 'as', 'otherwise', 'ten', 'two', 'up', 'us', 'onto', 'through', '‘re', '‘s', 'when', 'cannot', 'have', 'any', 'what', 'everyone', 'whether', 'this', 'less', 'our', 'others', 'hereupon', 'why', 'than', 'whom', 'were', 'an', 'latter', 'at', 'still', 'next', 'beforehand', 'side', 'five', 'using', 'give', 'until', 'n’t', 'even', 'which', 'against', 'already', 'sometimes', 'these', 'whoever', 'unless', 'most', 'done', 'none', 'serious', 'are', 'often', 'become', 'mostly', 'itself', 'same', 'by', 'from', 'hence', 'call', 'alone', 'thus', 'front', 'afterwards', 'that', 'beside', 'yourself', 'although', 'herein', 'last', 'such', 'whereupon', 'every', 'thereafter', 'therein', 'nor', 'another', "'ll", 'becomes', '‘d', 'along', 'will', '’m', 'thereby', 'show', 'latterly', 'regarding', 'where', 'formerly', 'all', 'my', 'keep', 'must', '’re', 'get', 'yours', 'since', 'third', 'throughout', 'hereafter', 'only', 'is', 'thence', 'just', 'beyond', 'though', 'am', 'empty', 'neither', 'how', 'may', "n't", 'each', 'four', 'after', 'into', '‘ve', 'becoming', 'meanwhile', 'i', 'behind', 'seems', 'then', 'please', 'doing', 'sixty', 'now', 'there', 'off', 'due', 'eleven', '’d', 'again', 'not', 'between', 'well', 'wherever', 'together', 'three', 'except', 'hereby', 'everything', 'toward', 'take', 'full', 'a', 'move', 'several', 'fifty', 'either', "'d", 'seemed', "'m", 'him', 'their', 'about', 'out', 'does', 'do', 'ca', 'across', 'ever', 'own', 'anyhow', 'among', 'wherein', 'put', 'also', 'really', 'see', 'being', 'fifteen', 'nine', 'further', 'almost', 'via', 'someone', '‘m', 'she', 'per', 'else', 'somehow', 'very', 'herself', 'therefore', 'you', 'ourselves', "'ve", 'make', 'once', 'n‘t', '’ve', 'hundred', 'say', 'nobody', 'rather', 'can', 'ours', 'namely', '‘ll', 'never', 'whole', 'part', 'seeming', 'twenty', 'yourselves', 'with', 'bottom', 'always', 'whereafter', '’ll', 'below', 'been', 'one', 'too', 'whereby', 'anywhere', 'back', 'anyway', 'some', 'but', 'could', 'within', 'both', 'themselves', 'its', 'if', 'made', 'hers', 'eight', 'go', 'whence', 'under', 'nothing', 'elsewhere', 'or', 'above', "'s", 'former', 'her', 're', 'be', 'it', 'indeed', 'on', 'other', 'many'}

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.vocab['beyond'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %%
my_sw = ['i','he','she','it','my','your','his','him','her']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin#\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words
# Out:
# 179
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
example_sent = "This is a sample sentence, And This showing off the stop words filtration."
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)
word_tokens
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'sentence',
#  ',',
#  'And',
#  'This',
#  'showing',
#  'off',
#  'the',
#  'stop',
#  'words',
#  'filtration',
#  '.']

# %%
# filtered_sentence = [w for w in word_tokens]

# print(word_tokens)
# print('---------------------------------')
# print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']

# %%
filtered_sentence = [w for w in word_tokens if not w in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['This', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'stop', 'words', 'filtration', '.']

# %%
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
Ar_SW1 = set(nltk.corpus.stopwords.words("arabic"))
print(len(Ar_SW1))
' | '.join(Ar_SW1)
# Out:
# 243
# 'بعض | ذاك | أما | عن | لستم | هلا | حيثما | ليسا | منها | ولو | بهن | إليك | هاك | أنت | بلى | الذي | ثمة | لك | آي | ها | تين | بمن | إلى | هاتان | منه | إذن | هذي | ذه | ليسوا | بخ | ذواتا | أن | ذين | ذات | حيث | وهو | إما | نعم | أقل | بس | هذين | خلا | تي | أولاء | وإذا | لستما | إنا | اللائي | أو | لوما | متى | بيد | هل | عسى | ته | كي | مذ | لعل | هاهنا | كأي | لكن | إليكما | ومن | كيفما | لو | مه | عند | سوف | فإن | إي | عدا | ليت | أينما | لولا | اللاتي | أنتم | ذلكما | أين | ليستا | مع | اللذان | أنى | لا | بعد | أكثر | إن | بهما | ذواتي | فإذا | ليس | اللواتي | مهما | هن | حتى | والذين | بكما | له | لن | ذي | ذلك | فيها | لكنما | بما | لكيلا | إليكن | هيت | شتان | دون | نحن | لست | حين | كليكما | سوى | ذانك | ماذا | وإذ | التي | فيما | ذينك | فيه | قد | هؤلاء | كيف | اللذين | أوه | كل | منذ | فلا | لم | كلتا | هو | تينك | عما | نحو | عليه | إليكم | اللتان | لها | أيها | أنتن | كما | هكذا | أي | ألا | لكم | هاته | هيا | هذه | هيهات | بل | ذلكم | هاتين | ليست | ذو | أنا | لكما | هنالك | بين | هي | إذا | ذوا | مما | كأن | ممن | أف | ما | بهم | ولا | كم | ثم | لهن | هنا | لنا | حبذا | بكن | بنا | هما | أنتما | به | ولكن | فمن | حاشا | كأنما | بي | ذا | لسنا | كليهما | لكي | وإن | غير | والذي | هناك | كلا | إنما | كأين | ذان | إذ | آها | كلاهما | عل | إلا | اللتيا | كلما | إنه | لاسيما | لستن | لهما | إيه | بكم | عليك | اللتين | كذلك | أولئك | كذا | لما | إذما | وما | هم | الذين | تلكما | أم | تلك | تلكم | على | لهم | بك | كيت | لي | هذا | هذان | بماذا | لسن | لئن | في | فيم | يا | من | هاتي | ريث | آه | لدى | ذلكن | بها'

# %%
from nltk.corpus import stopwords
Ar_SW2 = stopwords.words('arabic')
print(len(Ar_SW2))
' | '.join(Ar_SW2)
# Out:
# 248
# 'إذ | إذا | إذما | إذن | أف | أقل | أكثر | ألا | إلا | التي | الذي | الذين | اللاتي | اللائي | اللتان | اللتيا | اللتين | اللذان | اللذين | اللواتي | إلى | إليك | إليكم | إليكما | إليكن | أم | أما | أما | إما | أن | إن | إنا | أنا | أنت | أنتم | أنتما | أنتن | إنما | إنه | أنى | أنى | آه | آها | أو | أولاء | أولئك | أوه | آي | أي | أيها | إي | أين | أين | أينما | إيه | بخ | بس | بعد | بعض | بك | بكم | بكم | بكما | بكن | بل | بلى | بما | بماذا | بمن | بنا | به | بها | بهم | بهما | بهن | بي | بين | بيد | تلك | تلكم | تلكما | ته | تي | تين | تينك | ثم | ثمة | حاشا | حبذا | حتى | حيث | حيثما | حين | خلا | دون | ذا | ذات | ذاك | ذان | ذانك | ذلك | ذلكم | ذلكما | ذلكن | ذه | ذو | ذوا | ذواتا | ذواتي | ذي | ذين | ذينك | ريث | سوف | سوى | شتان | عدا | عسى | عل | على | عليك | عليه | عما | عن | عند | غير | فإذا | فإن | فلا | فمن | في | فيم | فيما | فيه | فيها | قد | كأن | كأنما | كأي | كأين | كذا | كذلك | كل | كلا | كلاهما | كلتا | كلما | كليكما | كليهما | كم | كم | كما | كي | كيت | كيف | كيفما | لا | لاسيما | لدى | لست | لستم | لستما | لستن | لسن | لسنا | لعل | لك | لكم | لكما | لكن | لكنما | لكي | لكيلا | لم | لما | لن | لنا | له | لها | لهم | لهما | لهن | لو | لولا | لوما | لي | لئن | ليت | ليس | ليسا | ليست | ليستا | ليسوا | ما | ماذا | متى | مذ | مع | مما | ممن | من | منه | منها | منذ | مه | مهما | نحن | نحو | نعم | ها | هاتان | هاته | هاتي | هاتين | هاك | هاهنا | هذا | هذان | هذه | هذي | هذين | هكذا | هل | هلا | هم | هما | هن | هنا | هناك | هنالك | هو | هؤلاء | هي | هيا | هيت | هيهات | والذي | والذين | وإذ | وإذا | وإن | ولا | ولكن | ولو | وما | ومن | وهو | يا'

# %%
# pip install arabicstopwords

# %%
import arabicstopwords.arabicstopwords as stp

# %%
len(stp.classed_stopwords_list())
# Out:
# 507

# %%
stp.classed_stopwords_list()
# Out:
# dict_keys(['حم', 'غداة', 'جنوب', 'ذواتا', 'حي', 'لازلنا', 'زمان', 'عوض', 'بنا', 'أجمع', 'ؤ', 'إيه', 'لدن', 'ها', 'ش', 'غرب', 'لازلتم', 'هج', 'هب', 'عسى', 'ل', 'آنفا', 'لازلتن', 'هن', 'هم', 'هل', 'هاؤم', 'ارتد', 'هي', 'هو', 'لازالتا', 'تلكما', 'وقت', 'أولئكم', 'نحو', 'حسب', 'نحن', 'لئن', 'اللذين', 'أب', 'أخ', 'قبل', 'بدون', 'مادامتا', 'بئس', 'د', 'ذا', 'لعمر', 'هاهنا', 'كما', 'لستم', 'لستن', 'حتى', 'لدى', 'ذه', 'ذي', 'ذو', 'أي', 'أو', 'أف', 'أن', 'أم', 'نعما', 'هيت', 'هيا', 'مابرح', 'حينما', 'هلا', 'إنما', 'جعل', 'كخ', 'ت', 'عما', 'بكن', 'بكم', 'مازلنا', 'غ', 'رويدك', 'دون', 'أولئك', 'كي', 'هؤلاء', 'لها', 'ي', 'مكانكما', 'كم', 'كل', 'مافتئتن', 'ماانفككتما', 'لعل', 'إنا', 'لازال', 'متى', 'مابرحوا', 'خلال', 'مازلتن', 'مازلتم', 'ثنا', 'راح', 'هلم', 'لولا', 'مابرحتما', 'مافتئت', 'مافتئتم', 'تان', 'مرة', 'أصلا', 'وشكان', 'كأنما', 'إياهما', 'أسفل', 'ص', 'أمامك', 'م', 'مادمتما', 'إياهم', 'ماانفكوا', 'استحال', 'إليك', 'أمسى', 'انبرى', 'مافتئتا', 'أنتم', 'لازالوا', 'أنتن', 'ليستا', 'ماانفككن', 'أوشك', 'طفق', 'لازالت', 'صه', 'لازالا', 'هناك', 'ليس', 'هاذين', 'مازالوا', 'إلا', 'سوف', 'ب', 'آمين', 'آناء', 'هاتين', 'ليت', 'و', 'أكثر', 'إلى', 'أثناء', 'ابن', 'بعدئذ', 'فلان', 'ليل', 'تين', 'أصبح', 'لكما', 'كأين', 'قد', 'ماانفككت', 'قط', 'لحظة', 'شمال', 'ثم', 'أجل', 'عليك', 'دونك', 'ذلكما', 'حما', 'أنت', 'التي', 'أوه', 'أنا', 'مثل', 'هذين', 'س', 'لازلتما', 'ك', 'أنى', 'حمو', 'حمي', 'هما', 'جير', 'أبدا', 'اللذان', 'عند', 'ظل', 'سرعان', 'خلف', 'تحول', 'هاته', 'هاتي', 'حوالى', 'جلل', 'تينك', 'أولاء', 'آنذاك', 'بعد', 'حين', 'ذيت', 'أيان', 'قلما', 'مازالا', 'خ', 'إزاء', 'بعض', 'فيما', 'لنا', 'مكانكن', 'تلكم', 'ذين', 'اللائي', 'تلقاء', 'خلا', 'حيث', 'مافتئوا', 'صار', 'أينما', 'يمين', 'رب', 'ماذا', 'لست', 'مافتئن', 'ذان', 'إياه', 'ذاك', 'ة', 'ن', 'حذار', 'ماانفكتا', 'ع', 'مادمتم', 'مادمتن', 'مابرحنا', 'ى', 'ذات', 'واها', 'أما', 'جدا', 'أمد', 'اللواتي', 'أمس', 'لسن', 'معاذ', 'الذين', 'حيثما', 'تحت', 'غير', 'حاشا', 'مافتئ', 'مابرحتن', 'مابرحتم', 'أمام', 'ج', 'أضحى', 'اللتيا', 'هاتان', 'هكذا', 'مابرحتا', 'كلتا', 'بضع', 'انقلب', 'اللتين', 'ساء', 'لستما', 'إليكن', 'إليكم', 'غدا', 'حاي', 'كلما', 'تبدل', 'مكانكم', 'كذلك', 'شتان', 'الآن', 'أولالك', 'إياي', 'ممن', 'إياك', 'كيت', 'بعدما', 'اخلولق', 'حرى', 'مادمنا', 'ط', 'ه', 'عاد', 'كيف', 'إياكم', 'إياكن', 'سبحان', 'هذان', 'أقبل', 'الألاء', 'مما', 'ليسوا', 'لما', 'ضحوة', 'مابرحا', 'آها', 'ماداموا', 'آ', 'كاد', 'عل', 'عن', 'مافتئتما', 'ز', 'لازلت', 'بيد', 'ق', 'ظ', 'ماداما', 'كان', 'كلاهما', 'بين', 'هيهات', 'إذا', 'إياكما', 'الذي', 'بل', 'نخ', 'طاق', 'أبو', 'أبي', 'هذا', 'لاسيما', 'هنا', 'ساءما', 'ذينك', 'آه', 'ساعة', 'ح', 'ابتدأ', 'صباح', 'ضمن', 'لكيلا', 'بمن', 'كيفما', 'سوى', 'إياها', 'تانك', 'أقل', 'إليكما', 'لئلا', 'كذا', 'آض', 'بما', 'ماانفكا', 'فيم', 'إياهن', 'فا', 'هذي', 'أبا', 'هذه', 'تجاه', 'شطر', 'حينئذ', 'أيضا', 'شرق', 'رجع', 'عامة', 'إذن', 'غروب', 'عندما', 'وراءك', 'إذ', 'ألا', 'لكي', 'مابرحت', 'لكن', 'لكم', 'يومئذ', 'لكنما', 'قبلما', 'بي', 'ذ', 'ماانفككنا', 'بك', 'بن', 'به', 'اللتان', 'ماانفككتم', 'تارة', 'بس', 'مابرحن', 'فقط', 'أنشأ', 'ماانفككتن', 'بخ', 'مثلما', 'شبه', 'بها', 'مازلتما', 'فوق', 'شهر', 'ماانفكت', 'إي', 'اللاتي', 'مازال', 'إن', 'كأن', 'كليهما', 'مافتئا', 'كليكما', 'شرع', 'ليسا', 'مكانك', 'ليست', 'وي', 'أعلى', 'لسنا', 'ثمة', 'لات', 'حسبما', 'ث', 'طالما', 'ذوا', 'مع', 'ماانفك', 'نفس', 'مذ', 'بكما', 'ذوي', 'ذوو', 'مه', 'من', 'حبذا', 'مادام', 'عدا', 'بينما', 'وراء', 'بات', 'عدس', 'وا', 'كلا', 'على', 'علق', 'مازلن', 'حار', 'وراءكن', 'مازالتا', 'وراءكم', 'مادمت', 'أخي', 'أخو', 'قام', 'ئ', 'إذما', 'أين', 'بطآن', 'الألى', 'ض', 'ذلكم', 'ذلكن', 'أية', 'نعم', 'أيا', 'هاك', 'ذواتي', 'مازلت', 'آنئذ', 'أخذ', 'ذلك', 'عندئذ', 'أخا', 'ويكأن', 'إيانا', 'كرب', 'لي', 'لو', 'لن', 'له', 'لم', 'لك', 'بلا', 'مادمن', 'ذانك', 'إما', 'هنالك', 'مادامت', 'ء', 'ريث', 'طق', 'جميع', 'حول', 'ر', 'مهما', 'تي', 'كأي', 'لوما', 'ته', 'ف', 'فو', 'في', 'أ', 'أول', 'مافتئنا', 'مساء', 'بماذا', 'عين', 'لا', 'جنب', 'تلك', 'بله', 'منذ', 'أنتما', 'وراءكما', 'لازلن', 'ما', 'بلى'])

# %%
len(stp.stopwords_list())
# Out:
# 13629

# %%
stp.stopwords_list()
# Out:
# dict_keys(['وعداهم', 'جنبنا', 'فباللتين', 'وبماذا', 'وأخونا', 'وكبعضكما', 'وعدانا', 'أفكعيننا', 'فإنهم', 'فإنهن', 'ولنا', 'كغربكن', 'بأنهما', 'أفبنفس', 'فبتلكم', 'أفبكلهما', 'فلشرقها', 'وكبعضنا', 'وبحسبكما', 'عليهما', 'بكلتا', 'أفبهنالك', 'لحسبي', 'أإلينا', 'وكابننا', 'بفينا', 'لحسبك', 'فلشرقهن', 'فلشرقهم', 'فبأخي', 'ولست', 'فلإليه', 'بغير', 'فباللتيا', 'ولكلكما', 'فلشهرهما', 'بأقلنا', 'فإنها', 'فلأخيكما', 'ألعن', 'ألعل', 'أفكبعضكما', 'أوعينكم', 'فكأقل', 'فلنفسهن', 'أوعينكن', 'ولعنهن', 'ولعلينا', 'ولعنهم', 'أفلغيرهم', 'أفلغيرهن', 'ألإنها', 'أخاه', 'ولأقلك', 'أخاي', 'وسويهن', 'ولأثناءي', 'أفلكأنها', 'ولأقلي', 'إلى', 'فلتلقاءها', 'ولغرب', 'ألازلتن', 'وكغيره', 'وكغيرك', 'وليتكن', 'وليتكم', 'وكغيري', 'وعندكم', 'أثناءكم', 'فشطركم', 'فشطركن', 'فلتلقاءهم', 'ومعاذهما', 'فلتلقاءهن', 'أوكعينكما', 'سبحانكما', 'فبجميعك', 'أخوه', 'فبجميعه', 'فلكنكما', 'أخوي', 'فبجميعي', 'لكنما', 'وكحمي', 'فلدنه', 'فكهناك', 'ألأجمعهن', 'أكأجمعي', 'فكهاتين', 'فبنفسكما', 'بشبه', 'حواليكن', 'بتلقاءنا', 'أكأجمعه', 'فأبينا', 'فذانك', 'أفلغيرها', 'ألإنهن', 'ألإنهم', 'وكحميكما', 'أفلكأنهم', 'وسويها', 'أفكلتا', 'أفلكأنهن', 'أولنحوكما', 'وأجمعكم', 'وأجمعكن', 'أفوراءهم', 'أفوراءهن', 'بذينك', 'أوكلما', 'أتلك', 'وكشبهكما', 'أونحونا', 'ولأثناءهما', 'شمالكن', 'وكعين', 'وبساعتكما', 'فلقلما', 'فبأبيهن', 'فزمانهن', 'فزمانهم', 'فمعنا', 'أوبعينكما', 'أفلستم', 'فلإنه', 'أذين', 'فلإنك', 'وغروبنا', 'أبعضها', 'ولسن', 'أمنكن', 'فلإني', 'أمنكم', 'فلأجمعي', 'كجنوبه', 'فزمانها', 'فبأبيها', 'كجنوبك', 'فلأجمعك', 'بعدنا', 'أفكحسب', 'فلأجمعه', 'كجنوبي', 'متى', 'فعندكم', 'فكعينكما', 'فعندكن', 'فبأية', 'أفوراءها', 'ثنا', 'أفلعلى', 'أفهكذا', 'بجنب', 'وكشرقي', 'ومازال', 'فكبعضهما', 'وكشرقه', 'فلفوقكن', 'ضمني', 'وكشرقك', 'لعمرها', 'فاللتيا', 'فبأننا', 'لشهرهن', 'لشهرهم', 'فجميعهما', 'حموي', 'فبسويه', 'ولحسبكن', 'حموه', 'ولحسبكم', 'أفككلهما', 'أوكجميعنا', 'أخاهن', 'أخاهم', 'بأثناءه', 'للتيا', 'ألعلينا', 'بأثناءي', 'ولجميعنا', 'لحسبه', 'فبسويك', 'وشرع', 'فحموكن', 'وللحظتنا', 'فحموكم', 'فكلحظتنا', 'وبأقلنا', 'أخلفكما', 'أخاها', 'فقلما', 'للتين', 'أفإليه', 'أفإليك', 'لتلك', 'ألكليكما', 'فمما', 'فذوينا', 'وهلا', 'فبفينا', 'لعمرهم', 'لعمرهن', 'ولغيركن', 'ولغيركم', 'لازالوا', 'أفليست', 'لشهرها', 'وآناء', 'أفليسا', 'أونفس', 'أولذاك', 'ماانفككن', 'وبلحظتك', 'أفتحتها', 'أونفسهن', 'أونفسهم', 'وجنوبك', 'وكشرقنا', 'أوذواتا', 'فيمينهم', 'وكأثناءكم', 'فخلفكن', 'ولذاتها', 'وكأثناءكن', 'لازالت', 'لعينكما', 'ولغروبي', 'لازالا', 'أفإنهن', 'وكحسبكن', 'وكحسبكم', 'أفإنهم', 'أوسويهم', 'أوسويهن', 'بالتي', 'لنحوه', 'لأيهن', 'لأيهم', 'ولليلكما', 'لنحوي', 'أفطالما', 'أوسويها', 'أفلعين', 'أغيرهما', 'بنحو', 'فبأسفلي', 'وتلقاءنا', 'ولغروبك', 'ابن', 'لأيها', 'تين', 'أبعض', 'أفتحتهم', 'ألمثلهما', 'أفتحتهن', 'أونفسها', 'أإليهما', 'فلإليك', 'ماانفككت', 'تجاهنا', 'ولذاتهم', 'ولذاتهن', 'وكأنكما', 'أفلإليهما', 'ومابرحتما', 'أفإنها', 'ساعتكن', 'فلجميع', 'لغربه', 'فكساعتهما', 'فلعامتكم', 'أكذا', 'أوعامتنا', 'معنا', 'أوذانك', 'أكلكما', 'ولكنما', 'أكذاك', 'بينهم', 'بينهن', 'فبنفسكم', 'أعليكما', 'أمنهما', 'وأيتهما', 'بأعلى', 'بأعلي', 'أوعنها', 'مثلهم', 'مثلهن', 'أوجميعهما', 'أفبمثلي', 'فكجنبي', 'بينها', 'أفبمثله', 'ألأناهما', 'فكجنبه', 'أفبمثلك', 'فعامتها', 'أفأجمعنا', 'فكجنبك', 'فلأنتم', 'فلأنتن', 'وبلحظتي', 'فيمينها', 'أوعنهن', 'أوعنهم', 'مثلها', 'بأجمعكما', 'ولأصبح', 'أكذي', 'أعامتهما', 'أفبعض', 'فكخلفها', 'أوأمامك', 'وإنكما', 'ألأجمعها', 'غروبهم', 'غروبهن', 'أولعين', 'بوقتنا', 'فكليلكن', 'وخلفكن', 'ولابن', 'فرويدك', 'أفسوينا', 'فلساعته', 'فحول', 'لقام', 'لذاتهن', 'أإنكن', 'فلذويهما', 'أإنكم', 'أومن', 'وكسوينا', 'أفلفيي', 'كأثناءها', 'أوغيركم', 'أوغيركن', 'لظل', 'أومما', 'أليمينهن', 'أليمينهم', 'أومع', 'أوبجميعكم', 'وكأبيكن', 'أوبجميعكن', 'كأثناءهم', 'كأثناءهن', 'صار', 'باللتين', 'أفبعينكما', 'فبأبي', 'حماكم', 'وكأبيكم', 'فكغروبنا', 'ذووهما', 'وبغير', 'ولأقله', 'فلحميكم', 'أفمعه', 'أمثلهما', 'فلجنبهما', 'لته', 'لتي', 'فبغربك', 'أكثرهم', 'كهاتين', 'وبعينها', 'كأعليهما', 'وأثناءكن', 'كلحظتها', 'وحتى', 'كخلفكما', 'مافتئوا', 'وحماك', 'أبغيركم', 'أبغيركن', 'فلراح', 'ولشبهكن', 'وأبوهم', 'أوكلك', 'جنوبهما', 'أوكله', 'بأخي', 'ولساعتهما',  ...

# %%
stp.is_stop(u'ممكن')
# Out:
# False

# %%
stp.is_stop(u'منكم')
# Out:
# True

# %%
stp.stopword_forms(u"على")
# Out:
# ['أفعليهم',
#  'ألعليكن',
#  'وعليهن',
#  'أفلعليكم',
#  'وعليكم',
#  'أفلعليك',
#  'أوعلي',
#  'فعلى',
#  'أفعليك',
#  'فعليه',
#  'فعليهما',
#  'أفلعليها',
#  'فعلينا',
#  'أوعليهما',
#  'ألعليهما',
#  'فلعليكن',
#  'ألعليكما',
#  'ولعليكما',
#  'علي',
#  'فعليك',
#  'عليهم',
#  'أعليك',
#  'وعليكن',
#  'علينا',
#  'وعليكما',
#  'أوعليكم',
#  'فلعليك',
#  'أوعلى',
#  'لعليه',
#  'أوعليهن',
#  'أولعليها',
#  'ألعلى',
#  'أفلعليهما',
#  'فلعليكم',
#  'وعليهم',
#  'ألعليك',
#  'أفعليكن',
#  'فعليكما',
#  'فعليهن',
#  'لعلى',
#  'فلعلينا',
#  'لعلي',
#  'لعليكما',
#  'ولعليك',
#  'فلعليكما',
#  'أعلي',
#  'ولعليكم',
#  'ولعليه',
#  'أعليكن',
#  'فلعلي',
#  'أولعليك',
#  'وعليهما',
#  'أوعليكما',
#  'أولعليكما',
#  'وعليك',
#  'فعليها',
#  'فلعليهما',
#  'عليكما',
#  'أعليهم',
#  'ألعليكم',
#  'أعليها',
#  'أعليه',
#  'أفعلى',
#  'أفعلينا',
#  'أفعليكم',
#  'أوعلينا',
#  'أفعليكما',
#  'أعلى',
#  'أعليكما',
#  'ولعلينا',
#  'أوعليهم',
#  'لعليكن',
#  'أفعليهن',
#  'عليه',
#  'عليهن',
#  'عليهما',
#  'فلعليه',
#  'فعلي',
#  'أفلعلى',
#  'ولعليها',
#  'ألعليها',
#  'أفلعليكن',
#  'أولعلي',
#  'أفلعلي',
#  'أفلعليهم',
#  'أعليهما',
#  'أولعلى',
#  'وعلى',
#  'ولعليهم',
#  'أعليكم',
#  'أولعليكم',
#  'لعليهما',
#  'أفلعلينا',
#  'عليكن',
#  'ولعليهما',
#  'أعلينا',
#  'أوعليك',
#  'وعلي',
#  'فعليهم',
#  'ألعلينا',
#  'أفعليهما',
#  'ألعليهن',
#  'أفعليها',
#  'وعليها',
#  'ألعليه',
#  'عليها',
#  'لعليهن',
#  'أفلعليكما',
#  'فعليكن',
#  'فلعلى',
#  'أولعليه',
#  'لعلينا',
#  'لعليها',
#  'أولعليهن',
#  'أفعلي',
#  'فعليكم',
#  'عليكم',
#  'ولعلي',
#  'أفلعليه',
#  'عليك',
#  'وعليه',
#  'أوعليكن',
#  'فلعليهم',
#  'أوعليها',
#  'ألعليهم',
#  'أولعلينا',
#  'ولعلى',
#  'وعلينا',
#  'ولعليكن',
#  'أولعليكن',
#  'أفلعليهن',
#  'ألعلي',
#  'أولعليهما',
#  'فلعليهن',
#  'ولعليهن',
#  'لعليهم',
#  'على',
#  'أعليهن',
#  'أولعليهم',
#  'لعليك',
#  'لعليكم',
#  'أوعليه',
#  'فلعليها',
#  'أفعليه']

# %%
len(stp.stopword_forms(u"على"))
# Out:
# 144
